# %%
img1=""""""

img2="""

AAAAAElFTkSuQmCC
"""

# %% [markdown]
# #Data Warehouse Lab 4: Uniting Data Lakes & Data Warehouse
#
# <br>
#
# ##Queiting the Complaints
# Health and Human Services department like many organizations has relied on tradiontal RDBMS warehouse for their reporting needs. Overtime performance of the data warehouse has continued to degrade as data volumes and users have grown. There have been many hardware and software upgrades over the years. All have been very costly in software licenses, new hardware, testing and migrating all the workloads at once, usually over a long weekend. Faced with growing compliants about slow performance the decision has been made to look for a better solution for data warehousing instead of doing yet another expensive time-consuming upgrade.
#
# <br>
#
# ## Overview
# Databricks SQL (DBSQL) is a powerful, integrated SQL analytics solution designed to provide seamless data querying, visualization, and collaboration across enterprise data environments. It combines the performance of data warehouses with the flexibility of data lakes.
#
# ## Key Features
#
# ### Performance and Scalability
# * Leverages Delta Lake for high-performance SQL queries
# * Supports massive parallel processing (MPP) architecture
# * Provides instant query acceleration with photon engine
# * Auto-scaling compute resources based on workload demands
#
# ### Integration Capabilities
# * Direct SQL access to Delta Lake tables
# * Seamless connection with BI tools like Tableau, Power BI
# * Native support for multiple data sources
# * Easy integration with existing data pipelines
#
# ### Query Management
# * Interactive SQL workspace
# * Query history and performance tracking
# * Advanced query optimization
# * Support for complex analytical queries and transformations
#
# ### Visualization and Dashboarding
# * Built-in SQL query editor
# * Interactive dashboard creation
# * Real-time data visualization
# * Sharing and collaboration features
#
# ## Use Cases
# * Enterprise reporting
# * Ad-hoc analytics
# * Data exploration
# * Business intelligence
# * Complex data transformations
#
# Databricks SQL bridges the gap between data engineering and business intelligence, providing a powerful, unified platform for modern data analytics.

# %% [markdown]
# ###Adhoc SQL
# Databricks includes an adhoc SQL editor. The SQL editor is similar to notebooks in that is allows for saving and sharing queries.
# Open the Claims Per Day and Combined Claims and Forecost query to launch the SQL editor and run the query. You will need to update the catalog to match your catalog name.

# %% [markdown]
# ###Lakeview Dashboards
# Lakeview dashboards are a convenient and easy to use vizulations tool.
# In addition to creating dashboards with the UI it is also possible to import dashboards from JSON files.
# In the cell below is a dashboard but before it can be imported it needs to be updated to reflacet your catalog name.
# Look for two instances of ***{catalog}*** and replace ***{catalog}*** with the name of your catalog.
# Copy the JSON text to a text editor, save the text file to your local machine. The extension of the file must be .lvdash.json in order to be able to import the file in the next step

# %% [markdown]
# {"datasets":[{"name":"be3bb181","displayName":"TMSIS Claims","query":"select DATE_TRUNC('DAY',DSCHRG_DT) DATE, round(sum(TOT_MDCD_PD_AMT), 0) as PAYMENT_AMOUNT, NULL FORECASE_AMOUNT\nfrom {catalog}.silver.tmsis_claims tc\nwhere DSCHRG_DT is not null\ngroup by DATE\nunion\nselect ts.discharge_date DATE, NULL PAYMENT_AMOUNT, round(sum(ts.total_amount)) as FORECASE_AMOUNT\nfrom {catalog}.gold.tmsis_forecast ts\ngroup by DATE"}],"pages":[{"name":"4a885d27","displayName":"Claims","layout":[{"widget":{"name":"c236a2d4","queries":[{"name":"main_query","query":{"datasetName":"be3bb181","fields":[{"name":"daily(DATE)","expression":"DATE_TRUNC(\"DAY\", `DATE`)"},{"name":"sum(PAYMENT_AMOUNT)","expression":"SUM(`PAYMENT_AMOUNT`)"},{"name":"sum(FORECASE_AMOUNT)","expression":"SUM(`FORECASE_AMOUNT`)"}],"disaggregated":false}}],"spec":{"version":3,"widgetType":"line","encodings":{"x":{"fieldName":"daily(DATE)","scale":{"type":"temporal"},"displayName":"DATE"},"y":{"scale":{"type":"quantitative"},"fields":[{"fieldName":"sum(PAYMENT_AMOUNT)","displayName":"Claims Amount"},{"fieldName":"sum(FORECASE_AMOUNT)","displayName":"Forecasted Claims Amount"}]},"label":{"show":false}}}},"position":{"x":0,"y":2,"width":6,"height":6}},{"widget":{"name":"d25d1fad","textbox_spec":"# TMSIS Claims Amount & 7 Day Forecast"},"position":{"x":0,"y":0,"width":6,"height":2}}]}]}

# %% [markdown]
# ###Import TMSIS Billing Dashboard

# %% [markdown]
# From the left vertical menu select Dashboards

# %%
from IPython import display
from base64 import b64decode

display.Image(b64decode(img1))

# %% [markdown]
# In the top right corner click the drop down triangle and select ***Import dashboard from file***
# In the file picker select the json file you created in the previous step

# %%
display.Image(b64decode(img2))

# %% [markdown]
# The dashboard will start refreshing after the import. If the dashboard doesn't start refreshing then look at your SQL to ensure the tables exist and the SQL is valid<br><br>
# Looking at the dashboard what information is being displayed?<br>
# If you were not using Databricks how would you achieve a similar result?<br>
# What challenges would you face that you wouldn't by using Databricks?<br><br>
#
# ###Congradulations on Completing the Lab
